# %%
from sklearn.model_selection import StratifiedKFold
import pandas as pd
ds = pd.read_excel('ml_project1_data.xlsx')
#print(ds["ID"])
ds.set_index('ID', inplace=True)
y = ds["Response"]
X = ds.drop(columns=["Response"])
skf = StratifiedKFold(n_splits=3, shuffle=True)
print(skf)
skf.get_n_splits(X, y)
for train_index, test_index in skf.split(X, y):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
# Out:
# StratifiedKFold(n_splits=3, random_state=None, shuffle=True)
# TRAIN: [   0    1    3 ... 2236 2237 2239] TEST: [   2    5    8   15   16   17   20   21   27   28   30   33   35   38
#    43   45   47   49   50   51   58   60   62   63   65   67   68   69
#    71   72   73   76   78   79   81   83   88   90   96   97   99  100
#   102  106  109  111  112  115  117  119  122  124  128  133  137  140
#   141  148  151  152  154  155  162  163  165  170  172  179  180  183
#   184  186  190  192  195  198  204  205  206  207  209  213  215  217
#   219  222  223  224  226  231  235  243  250  251  252  256  264  269
#   274  281  283  284  286  287  291  295  298  299  301  304  308  314
#   318  321  325  327  328  333  335  336  337  338  339  342  344  345
#   347  348  350  352  356  362  363  371  376  377  381  383  386  389
#   394  395  397  400  402  405  409  410  413  416  419  420  432  433
#   437  438  439  442  447  448  450  453  461  462  465  469  471  476
# ...

# %%
from sklearn.utils import class_weight
import numpy as np
class_weights = class_weight.compute_class_weight('balanced',np.unique(y_train), y_train)
#model.fit(X_train, y_train, class_weight=class_weights)
class_weights
# Out:
# array([0.58761805, 3.35329341])

# %%
#a = [0, 13, 15, 20, 13, 12]
b = [8, 10, 40, 23, 40, 80]
c = [1,2,3,4,5,6]
df = pd.DataFrame(columns=["a","b"], index = c)
#df["a"] = a
df["b"] =b

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
j = scaler.fit_transform(df[0:3])

h = scaler.transform(df[3:6])
# Out:
# C:\Users\Filipa\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:323: DataConversionWarning: Data with input dtype int64, object were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Users\Filipa\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:353: RuntimeWarning: All-NaN slice encountered
#   data_min = np.nanmin(X, axis=0)
# C:\Users\Filipa\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:354: RuntimeWarning: All-NaN slice encountered
#   data_max = np.nanmax(X, axis=0)

# %%
h
# Out:
# array([[    nan, 0.46875],
#        [    nan, 1.     ],
#        [    nan, 2.25   ]])

# %%
ds
# Out:
#        Year_Birth   Education Marital_Status    Income  Kidhome  Teenhome  \
# ID
# 6862         1971  Graduation       Divorced    1730.0        0         0
# 5376         1979  Graduation        Married    2447.0        1         0
# 11110        1973  Graduation         Single    3502.0        1         0
# 9931         1963         PhD        Married    4023.0        1         1
# 10311        1969  Graduation        Married    4428.0        0         1
# 3955         1965  Graduation       Divorced    4861.0        0         0
# 9303         1976  Graduation        Married    5305.0        0         1
# 5899         1950         PhD       Together    5648.0        1         1
# 4246         1982      Master         Single    6560.0        0         0
# 4303         1957         PhD       Together    6835.0        0         1
# 6237         1966         PhD         Single    7144.0        0         2
# 387          1976       Basic        Married    7500.0        0         0
# ...

# %%
from collections import Counter
from numpy.random import RandomState
from imblearn.over_sampling import SMOTENC
print('Original dataset shape (%s, %s)' % X.shape)
print('Original dataset samples per class {}'.format(Counter(y)))

# simulate the 2 last columns to be categorical features
sm = SMOTENC(random_state=42, categorical_features=[1, 2,6])
X_res, y_res = sm.fit_resample(X, y)
print('Resampled dataset samples per class {}'.format(Counter(y_res)))
# Out:
# Original dataset shape (2240, 27)
# Original dataset samples per class Counter({0: 1906, 1: 334})
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c3e96f75c548> in <module>
#       7 # simulate the 2 last columns to be categorical features
#       8 sm = SMOTENC(random_state=42, categorical_features=[1, 2,6])
# ----> 9 X_res, y_res = sm.fit_resample(X, y)
#      10 print('Resampled dataset samples per class {}'.format(Counter(y_res)))
#
# ~\Anaconda3\lib\site-packages\imblearn\base.py in fit_resample(self, X, y)
#      83             self.sampling_strategy, y, self._sampling_type)
#      84
# ---> 85         output = self._fit_resample(X, y)
#      86
#      87         if binarize_y:
#
# ~\Anaconda3\lib\site-packages\imblearn\over_sampling\_smote.py in _fit_resample(self, X, y)
#     945
#     946         X_continuous = X[:, self.continuous_features_]
# ...
